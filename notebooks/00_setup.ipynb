# %% [markdown]
# # Notebook 00 – Environment Setup
#
# **DigitAfrica Workshop 2026 – Identifying Epistemic Enclaves and Understanding Polarisation**
#
# This notebook verifies that your Python environment is correctly configured and all required libraries are installed.

# %%
# Check Python version
import sys
print(f"Python {sys.version}")

# %%
# Verify required packages
import importlib

required = [
    "numpy",
    "pandas",
    "matplotlib",
    "seaborn",
    "networkx",
    "cdlib",
    "sklearn",
    "tqdm",
]

for pkg in required:
    spec = importlib.util.find_spec(pkg)
    status = "✅ found" if spec is not None else "❌ missing"
    print(f"{pkg:20s} {status}")

# %% [markdown]
# If any package is missing, install it from the terminal:
#
# ```bash
# pip install -r ../requirements.txt
# ```
